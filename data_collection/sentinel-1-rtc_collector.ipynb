# %% [markdown]
# # Collect sentinel-1 rtc data from Planetary Computer

# %%
import geopandas as gpd
import planetary_computer
import pystac_client
import rioxarray
import numpy as np
import dask.array as da
from pathlib import Path
import warnings
import logging
from rasterio.errors import RasterioIOError
from functools import lru_cache
import os
import time 
from datetime import datetime
from tqdm import tqdm
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("sentinel1_processing.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# %%
# Paths and parameters
shapefile_path = "C:/Users/Jado/Documents/DFGF/Virunga_massif/Virunga_32735_massif.shp"
output_dir = Path("G:/Semester4/Innolab/eoAPI/data/Sentinel-1-RTC")
start_date = "2024-01-01"
end_date = "2024-12-31"
polarizations = ["vv", "vh"]
chunk_size = 2048 
max_retries = 5
initial_delay = 2

# %%
# Ensure output directories exist
output_dir.mkdir(parents=True, exist_ok=True)

# %%
def load_aoi():
    logger.info(f"Loading shapefile from {shapefile_path}")
    try:
        gdf = gpd.read_file(shapefile_path)
        if gdf.crs is None:
            raise ValueError("Shapefile has no CRS information")
        
        # Convert to WGS84 (EPSG:4326) for STAC API
        gdf = gdf.to_crs(epsg=4326)
        logger.info(f"Loaded shapefile with {len(gdf)} features, CRS: {gdf.crs}")
        return gdf
    except Exception as e:
        logger.error(f"Failed to load shapefile: {e}")
        raise

# %% [markdown]
# #### Connect to the planetary computer stac catalog

# %%
def connect_to_catalog(max_retries=5, initial_delay=2):
    retries = 0
    while retries < max_retries:
        try:
            catalog = pystac_client.Client.open(
                "https://planetarycomputer.microsoft.com/api/stac/v1",
                modifier=planetary_computer.sign_inplace,
            )
            logger.info("Successfully connected to STAC catalog")
            return catalog
        except Exception as e:
            retries += 1
            wait_time = initial_delay * (2 ** (retries - 1))  # Exponential backoff
            logger.warning(f"Connection attempt {retries} failed: {e}. Retrying in {wait_time}s...")
            time.sleep(wait_time)
    
    raise ConnectionError("Failed to connect to STAC catalog after maximum retries")

# %% [markdown]
# ### Search for sentinel-1 rtc items within the defined area of interest and time range

# %%
def search_sentinel1(catalog, aoi_geojson, time_range, max_retries=5, initial_delay=2):
    retries = 0
    while retries < max_retries:
        try:
            search = catalog.search(
                collections=["sentinel-1-rtc"],
                intersects=aoi_geojson,
                datetime=time_range
            )
            items = list(search.get_all_items())
            logger.info(f"🔍 Found {len(items)} Sentinel-1 items for {time_range}")
            
            # Sort by datetime
            sorted_items = sorted(items, key=lambda x: x.properties["datetime"])
            
            # Log item details
            for item in sorted_items:
                date = item.properties["datetime"].split("T")[0]
                orbit = item.properties.get("sat:orbit_state", "unknown")
                logger.debug(f"Item: {item.id}, Date: {date}, Orbit: {orbit}")
                
            return sorted_items
        except Exception as e:
            retries += 1
            wait_time = initial_delay * (2 ** (retries - 1))
            logger.warning(f"Search attempt {retries} failed: {e}. Retrying in {wait_time}s...")
            time.sleep(wait_time)
    
    raise ConnectionError("Failed to search items after maximum retries")

# %% [markdown]
# ### Get a signed url for accessing the datasets

# %%
@lru_cache(maxsize=None)
def get_signed_url(href):
    try:
        return planetary_computer.sign(href)
    except Exception as e:
        logger.error(f"Failed to get signed URL for {href}: {e}")
        raise

# %% [markdown]
# ### Clipping to the aoi

# %%
def process_and_clip_band(signed_url, output_path, gdf, crs_target="EPSG:4326", max_retries=3):
    retries = 0
    while retries < max_retries:
        try:
            with rioxarray.open_rasterio(signed_url, masked=True, chunks={"x": chunk_size, "y": chunk_size}) as ds:
                # Check if we need to reproject
                if ds.rio.crs != crs_target:
                    ds_repr = ds.rio.reproject(crs_target)
                else:
                    ds_repr = ds
                    
                # Clip to geometry
                clipped = ds_repr.rio.clip(gdf.geometry, gdf.crs, all_touched=True, drop=True)
                
                # Force computation with Dask
                clipped = clipped.compute()
                
                # Save to file
                clipped.rio.to_raster(output_path)
                logger.info(f"✅ Processed and saved: {output_path}")
                return True
        except RasterioIOError as e:
            retries += 1
            wait_time = 2 * (2 ** (retries - 1))
            logger.warning(f"IO error processing band (attempt {retries}/{max_retries}): {e}. Retrying in {wait_time}s...")
            time.sleep(wait_time)
        except Exception as e:
            logger.error(f"❌ Error processing band: {e}")
            return False
    
    logger.error(f"Failed to process band after {max_retries} attempts")
    return False

# %% [markdown]
# ### Main execution

# %%
start_time = datetime.now()
logger.info(f"Starting Sentinel-1 RTC data collection at {start_time}")
# Out:
# 2025-03-23 22:17:49,401 - INFO - Starting Sentinel-1 RTC data collection at 2025-03-23 22:17:49.401128

# %%
try:
    # Load AOI
    gdf = load_aoi()
    aoi_geojson = gdf.unary_union.__geo_interface__
    
    # Connect to catalog
    catalog = connect_to_catalog(max_retries=max_retries, initial_delay=initial_delay)
    
    # Search for items
    time_range = f"{start_date}/{end_date}"
    items = search_sentinel1(catalog, aoi_geojson, time_range, max_retries=max_retries, initial_delay=initial_delay)
    
    if not items:
        logger.warning("No Sentinel-1 items found for the specified parameters")
    else:
        # Process each item with progress bar
        successful_items = 0
        failed_items = 0
        skipped_items = 0
        
        for item in tqdm(items, desc="Processing items"):
            item_dir = output_dir / item.id
            item_dir.mkdir(parents=True, exist_ok=True)
            
            orbit_direction = item.properties.get("sat:orbit_state", "unknown")
            date = item.properties["datetime"].split("T")[0]
            
            logger.info(f"Processing item {item.id} from {date} (orbit: {orbit_direction})")
            
            item_success = True
            item_skipped = True
            
            # Process each polarization
            for polarization in polarizations:
                asset = item.assets.get(polarization)
                if not asset:
                    logger.warning(f"No {polarization} asset found for item {item.id}")
                    continue
                
                output_path = item_dir / f"sentinel1_{polarization}_{date}.tif"
                
                # Skip if already exists
                if output_path.exists():
                    logger.info(f"📁 Skipping (already exists): {output_path}")
                    continue
                
                item_skipped = False  # At least one band is being processed
                
                # Get signed URL and process
                try:
                    signed_url = get_signed_url(asset.href)
                    success = process_and_clip_band(signed_url, output_path, gdf, max_retries=max_retries)
                    
                    if not success:
                        logger.warning(f"Failed to process {polarization} for item {item.id}")
                        item_success = False
                except Exception as e:
                    logger.error(f"Error getting signed URL or processing {polarization} for item {item.id}: {e}")
                    item_success = False
            
            if item_skipped:
                skipped_items += 1
            elif item_success:
                successful_items += 1
            else:
                failed_items += 1
        
        logger.info(f"Processing summary: {successful_items} successful, {failed_items} failed, {skipped_items} skipped items")
    
    end_time = datetime.now()
    duration = end_time - start_time
    logger.info(f"Processing completed in {duration}")
    
except Exception as e:
    logger.error(f"An error occurred during processing: {e}", exc_info=True)
# Out:
# 2025-03-23 22:17:49,918 - INFO - Loading shapefile from C:/Users/Jado/Documents/DFGF/Virunga_massif/Virunga_32735_massif.shp
# 2025-03-23 22:17:50,005 - INFO - Loaded shapefile with 1 features, CRS: EPSG:4326
# 2025-03-23 22:17:50,164 - INFO - Successfully connected to STAC catalog
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f50d' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 11, in <module>
#     items = search_sentinel1(catalog, aoi_geojson, time_range, max_retries=max_retries, initial_delay=initial_delay)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\2892826690.py", line 11, in search_sentinel1
#     logger.info(f"🔍 Found {len(items)} Sentinel-1 items for {time_range}")
# Message: '🔍 Found 50 Sentinel-1 items for 2024-01-01/2024-12-31'
# Arguments: ()
# 2025-03-23 22:17:51,006 - INFO - 🔍 Found 50 Sentinel-1 items for 2024-01-01/2024-12-31
# 2025-03-23 22:17:51,150 - INFO - Processing item S1A_IW_GRDH_1SDV_20240110T162124_20240110T162149_052046_064A3E_rtc from 2024-01-10 (orbit: ascending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240110T162124_20240110T162149_052046_064A3E_rtc\\sentinel1_vv_2024-01-10.tif'
# Arguments: ()
# 2025-03-23 22:17:51,152 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240110T162124_20240110T162149_052046_064A3E_rtc\sentinel1_vv_2024-01-10.tif
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240110T162124_20240110T162149_052046_064A3E_rtc\\sentinel1_vh_2024-01-10.tif'
# Arguments: ()
# 2025-03-23 22:17:51,155 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240110T162124_20240110T162149_052046_064A3E_rtc\sentinel1_vh_2024-01-10.tif
# 2025-03-23 22:17:51,160 - INFO - Processing item S1A_IW_GRDH_1SDV_20240112T034518_20240112T034543_052068_064AFC_rtc from 2024-01-12 (orbit: descending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240112T034518_20240112T034543_052068_064AFC_rtc\\sentinel1_vv_2024-01-12.tif'
# Arguments: ()
# 2025-03-23 22:17:51,161 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240112T034518_20240112T034543_052068_064AFC_rtc\sentinel1_vv_2024-01-12.tif
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240112T034518_20240112T034543_052068_064AFC_rtc\\sentinel1_vh_2024-01-12.tif'
# Arguments: ()
# 2025-03-23 22:17:51,164 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240112T034518_20240112T034543_052068_064AFC_rtc\sentinel1_vh_2024-01-12.tif
# 2025-03-23 22:17:51,167 - INFO - Processing item S1A_IW_GRDH_1SDV_20240122T162124_20240122T162149_052221_065021_rtc from 2024-01-22 (orbit: ascending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240122T162124_20240122T162149_052221_065021_rtc\\sentinel1_vv_2024-01-22.tif'
# Arguments: ()
# 2025-03-23 22:17:51,169 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240122T162124_20240122T162149_052221_065021_rtc\sentinel1_vv_2024-01-22.tif
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240122T162124_20240122T162149_052221_065021_rtc\\sentinel1_vh_2024-01-22.tif'
# Arguments: ()
# 2025-03-23 22:17:51,172 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240122T162124_20240122T162149_052221_065021_rtc\sentinel1_vh_2024-01-22.tif
# 2025-03-23 22:17:51,176 - INFO - Processing item S1A_IW_GRDH_1SDV_20240124T034517_20240124T034542_052243_0650DC_rtc from 2024-01-24 (orbit: descending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240124T034517_20240124T034542_052243_0650DC_rtc\\sentinel1_vv_2024-01-24.tif'
# Arguments: ()
# 2025-03-23 22:17:51,176 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240124T034517_20240124T034542_052243_0650DC_rtc\sentinel1_vv_2024-01-24.tif
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240124T034517_20240124T034542_052243_0650DC_rtc\\sentinel1_vh_2024-01-24.tif'
# Arguments: ()
# 2025-03-23 22:17:51,217 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240124T034517_20240124T034542_052243_0650DC_rtc\sentinel1_vh_2024-01-24.tif
# 2025-03-23 22:17:51,221 - INFO - Processing item S1A_IW_GRDH_1SDV_20240203T162124_20240203T162149_052396_06560C_rtc from 2024-02-03 (orbit: ascending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240203T162124_20240203T162149_052396_06560C_rtc\\sentinel1_vv_2024-02-03.tif'
# Arguments: ()
# 2025-03-23 22:17:51,222 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240203T162124_20240203T162149_052396_06560C_rtc\sentinel1_vv_2024-02-03.tif
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240203T162124_20240203T162149_052396_06560C_rtc\\sentinel1_vh_2024-02-03.tif'
# Arguments: ()
# 2025-03-23 22:17:51,224 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240203T162124_20240203T162149_052396_06560C_rtc\sentinel1_vh_2024-02-03.tif
# 2025-03-23 22:17:51,227 - INFO - Processing item S1A_IW_GRDH_1SDV_20240205T034517_20240205T034542_052418_0656D0_rtc from 2024-02-05 (orbit: descending)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Jado\anaconda3\Lib\logging\__init__.py", line 1113, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Jado\anaconda3\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4c1' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 608, in run_forever
#     self._run_once()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\base_events.py", line 1936, in _run_once
#     handle._run()
#   File "C:\Users\Jado\anaconda3\Lib\asyncio\events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Jado\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Jado\AppData\Local\Temp\ipykernel_25356\3209371108.py", line 44, in <module>
#     logger.info(f"📁 Skipping (already exists): {output_path}")
# Message: '📁 Skipping (already exists): G:\\Semester4\\Innolab\\eoAPI\\data\\Sentinel-1-RTC\\S1A_IW_GRDH_1SDV_20240205T034517_20240205T034542_052418_0656D0_rtc\\sentinel1_vv_2024-02-05.tif'
# Arguments: ()
# 2025-03-23 22:17:51,228 - INFO - 📁 Skipping (already exists): G:\Semester4\Innolab\eoAPI\data\Sentinel-1-RTC\S1A_IW_GRDH_1SDV_20240205T034517_20240205T034542_052418_0656D0_rtc\sentinel1_vv_2024-02-05.tif
# --- Logging error ---
# ...
# 2025-03-23 23:53:50,093 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:53:50,094 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:54:06,097 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:54:06,099 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:54:38,101 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:54:38,102 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241119T034516_20241119T034541_056618_06F1D5_rtc
# 2025-03-23 23:54:38,132 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:54:38,134 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:54:40,138 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:54:40,139 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:54:44,142 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:54:44,143 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-23 23:54:52,146 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:54:52,147 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:55:08,151 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:55:08,152 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:55:40,154 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:55:40,155 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241119T034516_20241119T034541_056618_06F1D5_rtc
# 2025-03-23 23:55:40,158 - INFO - Processing item S1A_IW_GRDH_1SDV_20241129T162122_20241129T162147_056771_06F7EB_rtc from 2024-11-29 (orbit: ascending)
# 2025-03-23 23:55:40,211 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:55:40,212 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:55:42,214 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:55:42,215 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:55:46,219 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:55:46,220 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-23 23:55:54,223 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:55:54,224 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:56:10,228 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:56:10,229 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:56:42,231 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:56:42,232 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241129T162122_20241129T162147_056771_06F7EB_rtc
# 2025-03-23 23:56:42,264 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:56:42,265 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:56:44,269 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:56:44,271 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:56:48,274 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:56:48,275 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-23 23:56:56,278 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:56:56,280 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:57:12,283 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:57:12,284 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:57:44,286 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:57:44,287 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241129T162122_20241129T162147_056771_06F7EB_rtc
# 2025-03-23 23:57:44,290 - INFO - Processing item S1A_IW_GRDH_1SDV_20241211T162121_20241211T162146_056946_06FEC3_rtc from 2024-12-11 (orbit: ascending)
# 2025-03-23 23:57:44,346 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:57:44,347 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:57:46,349 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:57:46,350 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:57:50,354 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:57:50,355 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-23 23:57:58,359 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:57:58,360 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:58:14,363 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:58:14,365 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:58:46,367 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:58:46,369 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241211T162121_20241211T162146_056946_06FEC3_rtc
# 2025-03-23 23:58:46,398 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:58:46,399 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:58:48,402 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:58:48,403 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:58:52,405 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:58:52,406 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-23 23:59:00,410 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:59:00,411 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-23 23:59:16,413 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:59:16,414 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-23 23:59:48,416 - ERROR - Failed to process band after 5 attempts
# 2025-03-23 23:59:48,418 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241211T162121_20241211T162146_056946_06FEC3_rtc
# 2025-03-23 23:59:48,421 - INFO - Processing item S1A_IW_GRDH_1SDV_20241213T034515_20241213T034540_056968_06FFA6_rtc from 2024-12-13 (orbit: descending)
# 2025-03-23 23:59:48,478 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:59:48,479 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-23 23:59:50,482 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:59:50,483 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-23 23:59:54,486 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-23 23:59:54,487 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:00:02,490 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:00:02,491 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:00:18,495 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:00:18,496 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:00:50,498 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:00:50,499 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241213T034515_20241213T034540_056968_06FFA6_rtc
# 2025-03-24 00:00:50,531 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:00:50,533 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-24 00:00:52,535 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:00:52,536 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-24 00:00:56,540 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:00:56,541 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:01:04,544 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:01:04,545 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:01:20,546 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:01:20,547 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:01:52,550 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:01:52,550 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241213T034515_20241213T034540_056968_06FFA6_rtc
# 2025-03-24 00:01:52,553 - INFO - Processing item S1A_IW_GRDH_1SDV_20241223T162120_20241223T162145_057121_0705CE_rtc from 2024-12-23 (orbit: ascending)
# 2025-03-24 00:01:52,608 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:01:52,609 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-24 00:01:54,612 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:01:54,613 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-24 00:01:58,617 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:01:58,618 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:02:06,622 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:02:06,623 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:02:22,625 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:02:22,626 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:02:54,629 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:02:54,630 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241223T162120_20241223T162145_057121_0705CE_rtc
# 2025-03-24 00:02:54,660 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:02:54,661 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-24 00:02:56,665 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:02:56,666 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-24 00:03:00,669 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:03:00,670 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:03:08,673 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:03:08,675 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:03:24,678 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:03:24,679 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:03:56,681 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:03:56,683 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241223T162120_20241223T162145_057121_0705CE_rtc
# 2025-03-24 00:03:56,686 - INFO - Processing item S1A_IW_GRDH_1SDV_20241225T034513_20241225T034538_057143_0706AF_rtc from 2024-12-25 (orbit: descending)
# 2025-03-24 00:03:56,740 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:03:56,741 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-24 00:03:58,745 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:03:58,746 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-24 00:04:02,750 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:04:02,751 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:04:10,754 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:04:10,755 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:04:26,759 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:04:26,760 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:04:58,762 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:04:58,762 - WARNING - Failed to process vv for item S1A_IW_GRDH_1SDV_20241225T034513_20241225T034538_057143_0706AF_rtc
# 2025-03-24 00:04:58,793 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:04:58,794 - WARNING - IO error processing band (attempt 1/5): HTTP response code: 403. Retrying in 2s...
# 2025-03-24 00:05:00,796 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:05:00,798 - WARNING - IO error processing band (attempt 2/5): HTTP response code: 403. Retrying in 4s...
# 2025-03-24 00:05:04,801 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:05:04,802 - WARNING - IO error processing band (attempt 3/5): HTTP response code: 403. Retrying in 8s...
# 2025-03-24 00:05:12,806 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:05:12,807 - WARNING - IO error processing band (attempt 4/5): HTTP response code: 403. Retrying in 16s...
# 2025-03-24 00:05:28,810 - INFO - GDAL signalled an error: err_no=11, msg='HTTP response code: 403'
# 2025-03-24 00:05:28,811 - WARNING - IO error processing band (attempt 5/5): HTTP response code: 403. Retrying in 32s...
# 2025-03-24 00:06:00,814 - ERROR - Failed to process band after 5 attempts
# 2025-03-24 00:06:00,814 - WARNING - Failed to process vh for item S1A_IW_GRDH_1SDV_20241225T034513_20241225T034538_057143_0706AF_rtc
# Processing items: 100%|█████████████████████████████████████████████████████████████| 50/50 [1:48:09<00:00, 129.80s/it]
# 2025-03-24 00:06:00,822 - INFO - Processing summary: 3 successful, 31 failed, 16 skipped items
# 2025-03-24 00:06:00,825 - INFO - Processing completed in 1:48:11.422698
